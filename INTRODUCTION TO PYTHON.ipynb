# %% [markdown]
# # History of Python

# %% [markdown]
# Python is one of the most popular dynamic programming languages among which are Java, Javascript, Go and C#. Although often considered a "scripting" language, it is actually a general purpose language.
#
# Guido Van Rossum is the creator and responsible for Python’s existence. It is a Dutch computer scientist who was in charge of designing Python and of thinking and defining all the possible ways of evolution of this popular programming language.

# %% [markdown]
# ![Guido-van-Rossum.jpg.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# A review of all its versions
# Python’s story begins with Guido Van Rossum starting its development in 1989 and starting to be implemented in February 1991, at which time the first public version was published: 0.9.0.
#
# Version 1.0, which was released in January 1994, version 2.0 was released in October 2000 and version 3.0 was released in December 2008.
#
# This first version of Python already included legacy classes, exception handling, functions and one of its fundamental features: modular operation. This allowed it to be a much cleaner and more accessible language for people with little programming skills. A feature that remains to this day.
#
# Version 1.0
#
# Python is a programming language that Van Rossum began developing while working at CWI. It was this research center that released version 1.2 of Python in 1995. As of this time, already detached from CWI, Van Rossum made the code even more accessible and by the year 2000, the main team of Python developers was switched to BeOpen.com to form the BeOpen Python Labs team.
#
# Python 1.6.1 is exactly the same as 1.6, with some bugs fixed and a new GPL-compatible license.
#
# Python version 1.6 had some problems with its license type until the Free Software Foundation (FSF) managed to change Python to a Free Software license, which would make it GPL compatible.
#
# Version 2.0
#
# The second version of Python was published in October 2000. A new version that included the generation of lists, one of the most important features of the language this programming language.
#
# In 2001, the Python Software Foundation was created, which from Python 2.1 owns all the code, documentation and language specifications.
#
# Older than this new feature, this new version of Python also included a new system by which programmers were able to make cyclical references and, in this way, Python could collect garbage within the code.
#
# Version 3.0
#
# The last major update to the history of Python occurred in 2008 with the release of version 3.0, which came to solve the main flaws in the design of this programming language.
#
# Although Python maintains its philosophy in this latest version, as a programming language it has been accumulating new and redundant ways of programming the same element. Hence the need for new versions that remove these duplicate builders.
#
# Python 3.0 breaks the backward compatibility of the language, as Python 2.x code should not necessarily run in Python 3.0 without any modification.
#
# The latest update to version 3 of Python has been released this October 2020. It is version 3.9. This programming language will not be updated again until October 2021.

# %% [markdown]
# ![History of python.png](data:image/png;base64,...)

# %% [markdown]
# #  Print statement

# %% [markdown]
# **Print text**
#
# The print() function in Python is used to print a specified message on the screen:

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# **Print values**
#
# The result of the print statement is a value:

# %%
x = 'Hello'
y = 'Python'
print(x,"to the",y)
# Out:
# Hello to the Python

# %% [markdown]
# **Solve Operations**
#
# Multiple mathematical operations can be solved:

# %%
print (8*9)
# Out:
# 72

# %% [markdown]
# **Print blank lines**
#
# Sometimes you need to print one blank line in your Python program:

# %%
print ("Hello World")
print (4 * "\n")
print ("Hello World")
# Out:
# Hello World
#
#
#
#
#
# Hello World

# %% [markdown]
# **Print end command**
#
# By default, print function in Python ends with a newline. This function comes with a parameter called ‘end.’ The default value of this parameter is ‘\n,’ i.e., the new line character.

# %%
print ("Welcome to", end = ' ') 
print ("Python")
# Out:
# Welcome to Python

# %% [markdown]
# # If-else statement

# %% [markdown]
# **If statement**
#
# Is used for decision-making operations. It contains a body of code which runs only when the condition given in the if statement is true.

# %%
age = int(input("How old are you? "))
if age <= 18:
    print("You’re still a baby")
if age > 18 and age <= 25:
    print("Quite a young man")
if age > 25:
    print("You're an old man")
# Out:
# How old are you? 28
# You're an old man

# %% [markdown]
# **Else Statement**
#
# The else keyword catches anything which isn't caught by the preceding conditions.

# %%
a = 200
b = 33
if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")
else:
  print("a is greater than b")
# Out:
# a is greater than b

# %% [markdown]
# **Elif Statement**
#
# Is pythons way of saying "if the previous conditions were not true, then try this condition".

# %%
a = 55
b = 55
if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")
# Out:
# a and b are equal

# %% [markdown]
# # Loops

# %% [markdown]
# **While loop**
#
# Is used to execute a block of statements repeatedly until a given condition is satisfied. And when the condition becomes false, the line immediately after the loop in the program is executed. While loop falls under the category of indefinite iteration.

# %%
i = 1
while i < 10:
  print(i)
  i += 1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %% [markdown]
# **For loop**
#
# Is a control flow statement that is used to repeatedly execute a group of statements as long as the condition is satisfied.Thus, a for loop is an iterative statement.

# %%
fruits = ["Apple", "Banana", "Cherry", "Pineapple"]
for fruits in fruits:
  print(fruits, end = ' ')
# Out:
# Apple Banana Cherry Pineapple

# %% [markdown]
# **List**
#
# Is a data structure in Python that is a mutable, or changeable, ordered sequence of elements. Each element or value that is inside of a list is called an item.
#
# They enable you to keep data together that belongs together, condense your code, and perform the same methods and operations on multiple values at once.

# %%
MyList = ["Apple", "Banana", "Cherry", "Pineapple"]
print(MyList[3])
# Out:
# Pineapple
